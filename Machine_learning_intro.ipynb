# %% [markdown]
# <a href="https://colab.research.google.com/github/OfomiMatthew/hamoye-ml-intro/blob/main/Machine_learning_intro.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
# fetching and reading dataset
df = pd.read_csv("FoodBalanceSheets_E_Africa_NOFLAG.csv",encoding="latin-1")
df
# Out:
#        Area Code      Area  Item Code           Item  Element Code  \
# 0              4   Algeria       2501     Population           511
# 1              4   Algeria       2501     Population          5301
# 2              4   Algeria       2901    Grand Total           664
# 3              4   Algeria       2901    Grand Total           674
# 4              4   Algeria       2901    Grand Total           684
# ...          ...       ...        ...            ...           ...
# 60938        181  Zimbabwe       2899  Miscellaneous          5142
# 60939        181  Zimbabwe       2899  Miscellaneous           645
# 60940        181  Zimbabwe       2899  Miscellaneous           664
# 60941        181  Zimbabwe       2899  Miscellaneous           674
# 60942        181  Zimbabwe       2899  Miscellaneous           684
#
#                                       Element             Unit     Y2014  \
# 0               Total Population - Both sexes     1000 persons  38924.00
# ...

# %%
#  getting data info
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 60943 entries, 0 to 60942
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Area Code     60943 non-null  int64
#  1   Area          60943 non-null  object
#  2   Item Code     60943 non-null  int64
#  3   Item          60943 non-null  object
#  4   Element Code  60943 non-null  int64
#  5   Element       60943 non-null  object
#  6   Unit          60943 non-null  object
#  7   Y2014         59354 non-null  float64
#  8   Y2015         59395 non-null  float64
#  9   Y2016         59408 non-null  float64
#  10  Y2017         59437 non-null  float64
#  11  Y2018         59507 non-null  float64
# dtypes: float64(5), int64(3), object(4)
# memory usage: 5.6+ MB

# %%
# getting shape of data
df.shape
# Out:
# (60943, 12)

# %%
#  getting rows and columns of data
df.iloc[:]
# Out:
#        Area Code      Area  Item Code           Item  Element Code  \
# 0              4   Algeria       2501     Population           511
# 1              4   Algeria       2501     Population          5301
# 2              4   Algeria       2901    Grand Total           664
# 3              4   Algeria       2901    Grand Total           674
# 4              4   Algeria       2901    Grand Total           684
# ...          ...       ...        ...            ...           ...
# 60938        181  Zimbabwe       2899  Miscellaneous          5142
# 60939        181  Zimbabwe       2899  Miscellaneous           645
# 60940        181  Zimbabwe       2899  Miscellaneous           664
# 60941        181  Zimbabwe       2899  Miscellaneous           674
# 60942        181  Zimbabwe       2899  Miscellaneous           684
#
#                                       Element             Unit     Y2014  \
# 0               Total Population - Both sexes     1000 persons  38924.00
# ...

# %%
# description of different parameters on dataset
df.describe()
# Out:
#           Area Code     Item Code  Element Code          Y2014          Y2015  \
# count  60943.000000  60943.000000  60943.000000   59354.000000   59395.000000
# mean     134.265576   2687.176706   3814.856456     134.196282     135.235966
# std       72.605709    146.055739   2212.007033    1567.663696    1603.403984
# min        4.000000   2501.000000    511.000000   -1796.000000   -3161.000000
# 25%       74.000000   2562.000000    684.000000       0.000000       0.000000
# 50%      136.000000   2630.000000   5142.000000       0.090000       0.080000
# 75%      195.000000   2775.000000   5511.000000       8.340000       8.460000
# max      276.000000   2961.000000   5911.000000  176405.000000  181137.000000
#
#                Y2016          Y2017          Y2018
# count   59408.000000   59437.000000   59507.000000
# mean      136.555222     140.917765     143.758381
# std      1640.007194    1671.862359    1710.782658
# min     -3225.000000   -1582.000000   -3396.000000
# ...

# %%
x_count = df['Area'].unique()
print(len(x_count))
# Out:
# 49

# %%
y = [(2, 4), (7, 8), (1, 5, 9)]
x = y[1][1]
print(x)
# Out:
# 8

# %%
madagascar_2015_data = df[(df['Area'] == 'Madagascar') & (df['Y2015'])]
madagascar_2015_data
# Out:
#        Area Code        Area  Item Code              Item  Element Code  \
# 30715        129  Madagascar       2501        Population           511
# 30717        129  Madagascar       2901       Grand Total           664
# 30718        129  Madagascar       2901       Grand Total           674
# 30719        129  Madagascar       2901       Grand Total           684
# 30720        129  Madagascar       2903  Vegetal Products           664
# ...          ...         ...        ...               ...           ...
# 32147        129  Madagascar       2899     Miscellaneous          5301
# 32149        129  Madagascar       2899     Miscellaneous          5142
# 32150        129  Madagascar       2899     Miscellaneous           645
# 32152        129  Madagascar       2899     Miscellaneous           674
# 32153        129  Madagascar       2899     Miscellaneous           684
#
#                                       Element             Unit     Y2014  \
# ...

# %%
df['Y2014'].isnull().sum()
# Out:
# 1589

# %%
grouped = df.groupby('Element').sum()
processing_2017_sum = grouped.loc['Processing', 'Y2017']
processing_2017_sum
# Out:
# 292836.0

# %%
correlation = df['Element Code'].corr(df['Y2014'])
print(correlation)
# Out:
# 0.024456819495221754

# %%
correlation = df['Element Code'].corr(df['Y2015'])
print(correlation)
# Out:
# 0.023889199301639956

# %%
correlation = df['Element Code'].corr(df['Y2016'])
print(correlation)
# Out:
# 0.023443997584961424

# %%
correlation = df['Element Code'].corr(df['Y2017'])
print(correlation)
# Out:
# 0.02425400776004575

# %%
correlation = df['Element Code'].corr(df['Y2018'])
print(correlation)
# Out:
# 0.02427857195351955
